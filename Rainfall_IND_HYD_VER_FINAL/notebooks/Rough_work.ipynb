# %%
#Importing important libraries
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import pickle
import holidays
import config
data_filename = 'count_dict.pickle'
count_dict = pd.read_pickle(config.DATA+'//'+data_filename)
items = [   ['Ginger Tea'],
            ['Chapathi(1 No)'],
            ['Veg Samosa','Veg Samosa(RP)'],
            ['Biscuits'],
            ['Poori Saagu','Poori Saagu(4CP)'],
            ['Aloo Onion Parota','Aloo Onion Parota (4CP)'],
            ['Veg Meal','Veg Meal(4CP)'],
            ['Egg Fried Rice','Egg Fried Rice(4CP)'],
            [ 'Lays','Lays ( MRP )','Lays ( MRP)'],
            [ 'Veg Fried Rice','Veg Fried Rice(4CP)'],
            [ 'Maggi Noodles(Plain)','Maggi Noodles(Plain) (RP)'],
            [ 'Omlet(RP)','Omlette'],
            [ 'Plain Parota','Plain Parota(4CP)']
        ]

for i in items:
    a = []
    for l in i:
        a.append(count_dict[l])
    df_item = pd.concat(a)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       8 import pickle
#       9 import holidays
# ---> 10 import config
#      11 data_filename = 'count_dict.pickle'
#      12 count_dict = pd.read_pickle(config.DATA+'//'+data_filename)
#
# ModuleNotFoundError: No module named 'config'

# %%
import pickle
with open('order_data.pickle', 'rb') as handle:
    e = pickle.load(handle)

# %%
e
# Out:
#                Restaurant                      Vendor Company  \
# 0       Metro Food Corner  Lets Celebrate and Click and Order
# 1       Metro Food Corner  Lets Celebrate and Click and Order
# 2       Metro Food Corner  Lets Celebrate and Click and Order
# 3       Metro Food Corner  Lets Celebrate and Click and Order
# 4       Metro Food Corner  Lets Celebrate and Click and Order
# ...                   ...                                 ...
# 25893  Go Tuck (FSL-GRTP)  Lets Celebrate and Click and Order
# 25894  Go Tuck (FSL-GRTP)  Lets Celebrate and Click and Order
# 25895  Go Tuck (FSL-GRTP)  Lets Celebrate and Click and Order
# 25896  Go Tuck (FSL-GRTP)  Lets Celebrate and Click and Order
# 25897  Go Tuck (FSL-GRTP)  Lets Celebrate and Click and Order
#
#        Delivering Outlet                Foodcourt     Order Id Token No  \
# 0                    NaN  Firstsource - GRTP (GF)  ORD11184634     O001
# 1                    NaN  Firstsource - GRTP (GF)  ORD11184635     O002
# ...
